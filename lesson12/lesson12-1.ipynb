# %%
from os.path import abspath,dirname,join

file_path:str = join(dirname(abspath(__name__)),'data','peoples.csv')
file_path
# Out:
# '/workspaces/20240701_python/lesson12/data/peoples.csv'

# %%
from csv import DictReader
from pprint import pprint

with open(file_path,encoding='utf-8',newline='') as file:
    reader = DictReader(file)
    pprint(list(reader))
# Out:
# [{'BMI': '25.06', '姓名': '黃志福', '狀態': '體重過重', '身高': '173', '體重': '75'},
#  {'BMI': '28.41', '姓名': '林珈發', '狀態': '輕度肥胖', '身高': '175', '體重': '87'},
#  {'BMI': '27.19', '姓名': '陳逸凡', '狀態': '輕度肥胖', '身高': '151', '體重': '62'},
#  {'BMI': '27.34', '姓名': '鄭憲定', '狀態': '輕度肥胖', '身高': '170', '體重': '79'},
#  {'BMI': '19.94', '姓名': '林士凱', '狀態': '體重正常', '身高': '172', '體重': '59'},
#  {'BMI': '30.48', '姓名': '林詠斌', '狀態': '中度肥胖', '身高': '162', '體重': '80'},
#  {'BMI': '19.71', '姓名': '吳麗卿', '狀態': '體重正常', '身高': '173', '體重': '59'},
#  {'BMI': '24.34', '姓名': '林佳慧', '狀態': '體重過重', '身高': '179', '體重': '78'},
#  {'BMI': '24.06', '姓名': '蔡士賢', '狀態': '體重過重', '身高': '173', '體重': '72'},
#  {'BMI': '20.45', '姓名': '黃偉剛', '狀態': '體重正常', '身高': '164', '體重': '55'},
#  {'BMI': '24.64', '姓名': '陳凱翔', '狀態': '體重過重', '身高': '189', '體重': '88'},
#  {'BMI': '22.31', '姓名': '張莉雯', '狀態': '體重正常', '身高': '187', '體重': '78'},
#  {'BMI': '32.83', '姓名': '王德城', '狀態': '中度肥胖', '身高': '159', '體重': '83'},
#  {'BMI': '14.13', '姓名': '林向鈺', '狀態': '體重過輕', '身高': '190', '體重': '51'},
#  {'BMI': '25.04', '姓名': '馬彥文', '狀態': '體重過重', '身高': '166', '體重': '69'},
#  {'BMI': '18.31', '姓名': '李美洋', '狀態': '體重過輕', '身高': '181', '體重': '60'},
#  {'BMI': '27.85', '姓名': '劉耿琦', '狀態': '輕度肥胖', '身高': '163', '體重': '74'},
#  {'BMI': '27.76', '姓名': '許芳如', '狀態': '輕度肥胖', '身高': '176', '體重': '86'},
#  {'BMI': '24.45', '姓名': '王士銘', '狀態': '體重過重', '身高': '182', '體重': '81'},
#  {'BMI': '23.01', '姓名': '郎慧萍', '狀態': '體重正常', '身高': '156', '體重': '56'},
#  {'BMI': '23.96', '姓名': '蘇婷婷', '狀態': '體重正常', '身高': '185', '體重': '82'},
#  {'BMI': '29.05', '姓名': '陳奇瑄', '狀態': '輕度肥胖', '身高': '176', '體重': '90'},
#  {'BMI': '29.06', '姓名': '劉林中', '狀態': '輕度肥胖', '身高': '169', '體重': '83'},
#  {'BMI': '19.49', '姓名': '黃必琪', '狀態': '體重正常', '身高': '174', '體重': '59'},
#  {'BMI': '18.08', '姓名': '賴心怡', '狀態': '體重過輕', '身高': '176', '體重': '56'},
#  {'BMI': '24.06', '姓名': '游倫城', '狀態': '體重過重', '身高': '173', '體重': '72'},
#  {'BMI': '16.33', '姓名': '林清英', '狀態': '體重過輕', '身高': '175', '體重': '50'},
#  {'BMI': '17.45', '姓名': '簡佳樺', '狀態': '體重過輕', '身高': '190', '體重': '63'},
#  {'BMI': '27.08', '姓名': '黃政甫', '狀態': '輕度肥胖', '身高': '174', '體重': '82'},
#  {'BMI': '23.71', '姓名': '楊易政', '狀態': '體重正常', '身高': '163', '體重': '63'},
#  {'BMI': '23.92', '姓名': '李進慧', '狀態': '體重正常', '身高': '184', '體重': '81'},
#  {'BMI': '22.28', '姓名': '余宗儒', '狀態': '體重正常', '身高': '176', '體重': '69'},
#  {'BMI': '25.65', '姓名': '胡芳瑜', '狀態': '體重過重', '身高': '164', '體重': '69'},
#  {'BMI': '16.85', '姓名': '翁鈺婷', '狀態': '體重過輕', '身高': '179', '體重': '54'},
#  {'BMI': '34.05', '姓名': '尚偉倫', '狀態': '中度肥胖', '身高': '158', '體重': '85'},
#  {'BMI': '19.6', '姓名': '李淑芳', '狀態': '體重正常', '身高': '166', '體重': '54'},
#  {'BMI': '16.3', '姓名': '張雅芬', '狀態': '體重過輕', '身高': '182', '體重': '54'},
#  {'BMI': '29.94', '姓名': '溫重意', '狀態': '輕度肥胖', '身高': '154', '體重': '71'},
#  {'BMI': '19.13', '姓名': '蔡明平', '狀態': '體重正常', '身高': '168', '體重': '54'},
#  {'BMI': '35.56', '姓名': '楊韻如', '狀態': '重度肥胖', '身高': '150', '體重': '80'},
#  {'BMI': '18.13', '姓名': '陳怡珊', '狀態': '體重過輕', '身高': '171', '體重': '53'},
#  {'BMI': '27.11', '姓名': '蔡士賢', '狀態': '輕度肥胖', '身高': '150', '體重': '61'},
#  {'BMI': '23.41', '姓名': '鄭淑珍', '狀態': '體重正常', '身高': '179', '體重': '75'},
#  {'BMI': '24.98', '姓名': '張嘉韋', '狀態': '體重過重', '身高': '165', '體重': '68'},
#  {'BMI': '30.86', '姓名': '李慶亮', '狀態': '中度肥胖', '身高': '160', '體重': '79'},
#  {'BMI': '26.04', '姓名': '謝哲維', '狀態': '體重過重', '身高': '158', '體重': '65'},
#  {'BMI': '23.16', '姓名': '翁均安', '狀態': '體重正常', '身高': '187', '體重': '81'},
#  {'BMI': '21.97', '姓名': '盧文啟', '狀態': '體重正常', '身高': '168', '體重': '62'},
#  {'BMI': '22.77', '姓名': '錢佩豪', '狀態': '體重正常', '身高': '154', '體重': '54'},
#  {'BMI': '22.94', '姓名': '劉萬季', '狀態': '體重正常', '身高': '159', '體重': '58'}]
